# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load the YOLO model
model = YOLO("yolov8n-seg.pt")  # load an official model

# Open the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    if not ret:
        print("Error: Failed to capture image.")
        break

    # Perform prediction
    results = model(frame)

    # Get the image with predictions
    img = results[0].plot()

    # Create a heatmap
    heatmap = np.zeros((img.shape[0], img.shape[1]), dtype=np.float32)

    # Overlay the prediction masks onto the heatmap
    if results[0].masks is not None:
        for mask in results[0].masks.data:
            mask = mask.cpu().numpy().squeeze()  # Convert mask to numpy array and remove single-dimensional entries
            mask_resized = cv2.resize(mask, (heatmap.shape[1], heatmap.shape[0]))  # Resize mask to match heatmap size
            heatmap = cv2.add(heatmap, mask_resized.astype(np.float32))

    # Normalize the heatmap
    heatmap = cv2.normalize(heatmap, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)

    # Convert heatmap to RGB
    heatmap_img = cv2.applyColorMap(np.uint8(255 * heatmap), cv2.COLORMAP_JET)

    # Combine the original image with the heatmap
    overlay_img = cv2.addWeighted(img, 0.6, heatmap_img, 0.4, 0)

    # Display the result
    cv2.imshow('Original Image with Predictions', img)
    cv2.imshow('Heatmap Overlay', overlay_img)

    # Press 'q' to quit the webcam stream
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# /Users/being/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 2024-07-16 19:02:49.395 Python[40492:2174705] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 5.3ms preprocess, 104.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# 2024-07-16 19:02:52.527 Python[40492:2174705] WARNING: Secure coding is automatically enabled for restorable state! However, not on all supported macOS versions of this application. Opt-in to secure coding explicitly by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState:.
#
# 0: 384x640 (no detections), 110.1ms
# Speed: 2.0ms preprocess, 110.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.1ms
# Speed: 2.1ms preprocess, 70.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.4ms
# Speed: 1.6ms preprocess, 70.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 136.8ms
# Speed: 14.0ms preprocess, 136.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.4ms
# Speed: 2.1ms preprocess, 88.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.5ms
# Speed: 1.9ms preprocess, 82.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.3ms
# Speed: 1.6ms preprocess, 70.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.4ms
# Speed: 2.2ms preprocess, 81.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.5ms
# Speed: 2.1ms preprocess, 57.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 129.3ms
# Speed: 2.9ms preprocess, 129.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.3ms
# Speed: 1.9ms preprocess, 71.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.8ms
# Speed: 2.3ms preprocess, 92.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.2ms
# Speed: 2.6ms preprocess, 77.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.8ms
# Speed: 1.8ms preprocess, 96.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.4ms
# Speed: 1.8ms preprocess, 89.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.9ms
# Speed: 2.0ms preprocess, 92.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.1ms
# Speed: 2.5ms preprocess, 88.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.5ms
# Speed: 1.6ms preprocess, 75.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.5ms
# Speed: 1.4ms preprocess, 92.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.8ms
# Speed: 1.7ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 133.7ms
# Speed: 2.6ms preprocess, 133.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.4ms
# Speed: 1.7ms preprocess, 72.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.1ms
# Speed: 2.2ms preprocess, 68.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.3ms
# Speed: 1.8ms preprocess, 64.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.2ms
# Speed: 2.0ms preprocess, 64.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.9ms
# Speed: 1.3ms preprocess, 61.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.7ms
# Speed: 1.4ms preprocess, 57.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.7ms
# Speed: 2.2ms preprocess, 69.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.2ms
# Speed: 2.4ms preprocess, 59.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.6ms
# Speed: 2.8ms preprocess, 63.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.0ms
# Speed: 2.1ms preprocess, 62.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.4ms
# Speed: 2.1ms preprocess, 66.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.8ms
# Speed: 1.7ms preprocess, 57.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.6ms
# Speed: 2.3ms preprocess, 61.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.3ms
# Speed: 2.2ms preprocess, 74.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.4ms
# Speed: 1.5ms preprocess, 84.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.2ms
# Speed: 2.3ms preprocess, 98.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.0ms
# Speed: 3.6ms preprocess, 76.0ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.8ms
# Speed: 1.6ms preprocess, 84.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.3ms
# Speed: 1.8ms preprocess, 96.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 120.9ms
# Speed: 2.1ms preprocess, 120.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.7ms
# Speed: 1.5ms preprocess, 111.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.0ms
# Speed: 3.1ms preprocess, 107.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 62.9ms
# Speed: 1.9ms preprocess, 62.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 chairs, 71.3ms
# Speed: 1.6ms preprocess, 71.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.2ms
# Speed: 1.6ms preprocess, 65.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 1 cell phone, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 remote, 56.3ms
# Speed: 1.9ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 toothbrush, 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 149.8ms
# Speed: 1.9ms preprocess, 149.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.7ms
# Speed: 1.7ms preprocess, 78.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.9ms
# Speed: 2.7ms preprocess, 94.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.0ms
# Speed: 1.4ms preprocess, 62.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.3ms
# Speed: 1.4ms preprocess, 61.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.8ms
# Speed: 1.8ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 1 remote, 62.7ms
# Speed: 1.5ms preprocess, 62.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.8ms
# Speed: 2.4ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.1ms
# Speed: 1.9ms preprocess, 67.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 5.2ms preprocess, 69.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bed, 68.3ms
# Speed: 2.0ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 1 couch, 68.1ms
# Speed: 2.0ms preprocess, 68.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 couch, 63.0ms
# Speed: 2.1ms preprocess, 63.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.3ms
# Speed: 1.7ms preprocess, 58.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 4 chairs, 1 couch, 67.4ms
# Speed: 2.0ms preprocess, 67.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 chairs, 1 couch, 65.6ms
# Speed: 2.1ms preprocess, 65.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 3 chairs, 1 couch, 1 dining table, 62.4ms
# Speed: 1.5ms preprocess, 62.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 5 chairs, 1 couch, 2 dining tables, 62.4ms
# Speed: 1.6ms preprocess, 62.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 chairs, 1 couch, 65.8ms
# Speed: 2.1ms preprocess, 65.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 5 chairs, 1 couch, 1 dining table, 64.0ms
# Speed: 1.5ms preprocess, 64.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 chairs, 2 couchs, 1 dining table, 63.0ms
# Speed: 1.8ms preprocess, 63.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 4 chairs, 1 couch, 63.4ms
# Speed: 2.1ms preprocess, 63.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bottles, 4 chairs, 1 couch, 61.6ms
# Speed: 1.6ms preprocess, 61.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 4 chairs, 1 couch, 1 dining table, 63.2ms
# Speed: 2.1ms preprocess, 63.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 cup, 3 chairs, 2 couchs, 1 dining table, 65.9ms
# Speed: 1.9ms preprocess, 65.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 3 chairs, 1 couch, 64.6ms
# Speed: 1.9ms preprocess, 64.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 chairs, 1 couch, 62.1ms
# Speed: 1.8ms preprocess, 62.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 chairs, 2 couchs, 65.6ms
# Speed: 1.9ms preprocess, 65.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.0ms
# Speed: 1.7ms preprocess, 60.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 chairs, 2 couchs, 2 dining tables, 1 tv, 1 laptop, 61.3ms
# Speed: 2.0ms preprocess, 61.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 chairs, 1 couch, 92.4ms
# Speed: 1.7ms preprocess, 92.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 chairs, 2 couchs, 1 dining table, 56.9ms
# Speed: 1.8ms preprocess, 56.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 chairs, 1 couch, 2 dining tables, 58.9ms
# Speed: 1.5ms preprocess, 58.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 chairs, 2 couchs, 1 dining table, 1 mouse, 69.0ms
# Speed: 2.4ms preprocess, 69.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 17 chairs, 2 couchs, 1 dining table, 1 laptop, 68.8ms
# Speed: 1.7ms preprocess, 68.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 19 chairs, 1 couch, 2 dining tables, 64.5ms
# Speed: 2.2ms preprocess, 64.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bowl, 10 chairs, 2 couchs, 63.8ms
# Speed: 1.5ms preprocess, 63.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 chairs, 4 couchs, 1 dining table, 1 laptop, 64.8ms
# Speed: 1.5ms preprocess, 64.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 12 chairs, 3 couchs, 1 dining table, 1 tv, 2 laptops, 61.2ms
# Speed: 2.0ms preprocess, 61.2ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14 chairs, 3 couchs, 1 dining table, 1 tv, 1 mouse, 65.9ms
# Speed: 1.5ms preprocess, 65.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 chairs, 1 couch, 64.6ms
# Speed: 1.4ms preprocess, 64.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 chairs, 1 couch, 1 dining table, 1 tv, 2 laptops, 1 cell phone, 57.1ms
# Speed: 1.6ms preprocess, 57.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 suitcase, 12 chairs, 2 couchs, 1 dining table, 1 tv, 2 laptops, 69.4ms
# Speed: 2.1ms preprocess, 69.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14 chairs, 3 couchs, 1 dining table, 1 laptop, 63.8ms
# Speed: 2.3ms preprocess, 63.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 handbag, 12 chairs, 2 couchs, 1 dining table, 2 laptops, 59.0ms
# Speed: 1.6ms preprocess, 59.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 handbag, 14 chairs, 2 couchs, 1 dining table, 1 tv, 67.7ms
# Speed: 1.8ms preprocess, 67.7ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 donut, 13 chairs, 2 couchs, 1 dining table, 64.7ms
# Speed: 1.4ms preprocess, 64.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 chairs, 2 couchs, 1 dining table, 58.0ms
# Speed: 2.2ms preprocess, 58.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 10 chairs, 3 couchs, 1 dining table, 1 tv, 1 laptop, 68.0ms
# Speed: 1.7ms preprocess, 68.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 handbag, 1 donut, 12 chairs, 3 couchs, 1 dining table, 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 handbag, 1 suitcase, 1 donut, 12 chairs, 3 couchs, 1 dining table, 1 laptop, 60.8ms
# Speed: 2.3ms preprocess, 60.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 donut, 10 chairs, 3 couchs, 1 dining table, 1 tv, 62.2ms
# Speed: 1.7ms preprocess, 62.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 12 chairs, 3 couchs, 1 dining table, 1 laptop, 58.1ms
# Speed: 1.9ms preprocess, 58.1ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 suitcase, 10 chairs, 2 couchs, 1 dining table, 68.4ms
# Speed: 2.6ms preprocess, 68.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 suitcase, 11 chairs, 3 couchs, 1 dining table, 2 laptops, 59.8ms
# Speed: 1.4ms preprocess, 59.8ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 13 chairs, 3 couchs, 1 dining table, 60.6ms
# Speed: 1.8ms preprocess, 60.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 suitcase, 10 chairs, 3 couchs, 1 dining table, 1 laptop, 69.6ms
# Speed: 1.7ms preprocess, 69.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 suitcase, 11 chairs, 3 couchs, 1 dining table, 68.4ms
# Speed: 1.7ms preprocess, 68.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 suitcase, 9 chairs, 3 couchs, 1 dining table, 1 laptop, 63.7ms
# Speed: 2.4ms preprocess, 63.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 chairs, 3 couchs, 1 dining table, 73.3ms
# Speed: 2.1ms preprocess, 73.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 suitcase, 10 chairs, 2 couchs, 1 dining table, 79.6ms
# Speed: 1.7ms preprocess, 79.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 suitcase, 10 chairs, 2 couchs, 1 dining table, 67.5ms
# Speed: 1.7ms preprocess, 67.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 suitcase, 9 chairs, 3 couchs, 1 dining table, 60.6ms
# Speed: 1.9ms preprocess, 60.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 chairs, 3 couchs, 1 dining table, 2 laptops, 62.9ms
# Speed: 2.2ms preprocess, 62.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 handbag, 1 suitcase, 13 chairs, 2 couchs, 1 dining table, 60.6ms
# Speed: 3.0ms preprocess, 60.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 12 chairs, 3 couchs, 1 dining table, 65.4ms
# Speed: 1.4ms preprocess, 65.4ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 hot dog, 12 chairs, 3 couchs, 1 dining table, 68.0ms
# Speed: 1.7ms preprocess, 68.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 suitcase, 11 chairs, 2 couchs, 1 dining table, 1 tv, 1 laptop, 59.2ms
# Speed: 1.7ms preprocess, 59.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 12 chairs, 3 couchs, 1 dining table, 1 tv, 1 laptop, 62.2ms
# Speed: 2.2ms preprocess, 62.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 chairs, 3 couchs, 1 dining table, 1 laptop, 60.2ms
# Speed: 1.7ms preprocess, 60.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 13 chairs, 2 couchs, 1 dining table, 1 laptop, 58.9ms
# Speed: 1.9ms preprocess, 58.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 11 chairs, 2 couchs, 1 dining table, 1 laptop, 54.6ms
# Speed: 1.7ms preprocess, 54.6ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 12 chairs, 2 couchs, 1 dining table, 2 laptops, 64.0ms
# Speed: 1.8ms preprocess, 64.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 14 chairs, 2 couchs, 1 tv, 2 laptops, 64.7ms
# Speed: 1.6ms preprocess, 64.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bowl, 2 chairs, 60.7ms
# Speed: 2.3ms preprocess, 60.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 donut, 9 chairs, 1 couch, 1 laptop, 1 mouse, 90.1ms
# Speed: 1.5ms preprocess, 90.1ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 handbag, 7 chairs, 1 couch, 1 laptop, 60.1ms
# Speed: 1.6ms preprocess, 60.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 chairs, 1 couch, 1 laptop, 65.0ms
# Speed: 2.3ms preprocess, 65.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 chairs, 1 couch, 1 dining table, 60.9ms
# Speed: 1.7ms preprocess, 60.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 chairs, 1 couch, 1 dining table, 61.0ms
# Speed: 2.1ms preprocess, 61.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 chairs, 1 couch, 2 dining tables, 62.6ms
# Speed: 1.6ms preprocess, 62.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 handbag, 1 suitcase, 8 chairs, 1 couch, 64.7ms
# Speed: 1.4ms preprocess, 64.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 backpack, 1 handbag, 9 chairs, 1 couch, 2 dining tables, 1 laptop, 69.2ms
# Speed: 2.1ms preprocess, 69.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 backpack, 7 chairs, 1 couch, 1 dining table, 63.2ms
# Speed: 2.3ms preprocess, 63.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 backpack, 8 chairs, 1 couch, 1 dining table, 58.0ms
# Speed: 1.5ms preprocess, 58.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 chairs, 1 couch, 1 dining table, 57.6ms
# Speed: 1.4ms preprocess, 57.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 1 couch, 1 dining table, 57.0ms
# Speed: 1.8ms preprocess, 57.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 backpack, 8 chairs, 1 couch, 1 dining table, 67.4ms
# Speed: 1.7ms preprocess, 67.4ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 1 couch, 1 dining table, 1 tv, 61.3ms
# Speed: 1.4ms preprocess, 61.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 backpack, 10 chairs, 1 couch, 1 dining table, 1 tv, 59.2ms
# Speed: 2.1ms preprocess, 59.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 chairs, 1 couch, 1 dining table, 1 tv, 63.4ms
# Speed: 1.4ms preprocess, 63.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 chairs, 1 couch, 1 tv, 63.9ms
# Speed: 2.5ms preprocess, 63.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 chairs, 1 couch, 2 dining tables, 2 tvs, 60.6ms
# Speed: 1.4ms preprocess, 60.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 chairs, 1 couch, 1 dining table, 1 tv, 64.3ms
# Speed: 1.4ms preprocess, 64.3ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 backpack, 1 handbag, 10 chairs, 1 couch, 1 dining table, 2 tvs, 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 chairs, 1 couch, 1 dining table, 63.2ms
# Speed: 2.3ms preprocess, 63.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 10 chairs, 1 couch, 1 dining table, 68.9ms
# Speed: 2.1ms preprocess, 68.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 10 chairs, 1 couch, 1 dining table, 56.8ms
# Speed: 1.5ms preprocess, 56.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 chairs, 1 couch, 1 dining table, 1 tv, 68.0ms
# Speed: 19.3ms preprocess, 68.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 chairs, 1 couch, 1 dining table, 1 tv, 63.8ms
# Speed: 2.1ms preprocess, 63.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 chairs, 1 couch, 1 dining table, 65.9ms
# Speed: 1.6ms preprocess, 65.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 chairs, 1 couch, 1 dining table, 61.5ms
# Speed: 2.1ms preprocess, 61.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 12 chairs, 1 couch, 1 dining table, 1 tv, 111.0ms
# Speed: 4.7ms preprocess, 111.0ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 11 chairs, 1 couch, 1 dining table, 59.6ms
# Speed: 1.8ms preprocess, 59.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 chairs, 1 couch, 1 dining table, 58.7ms
# Speed: 1.9ms preprocess, 58.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 1 handbag, 8 chairs, 1 couch, 1 dining table, 1 cell phone, 58.1ms
# Speed: 1.3ms preprocess, 58.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 10 chairs, 1 couch, 1 dining table, 1 laptop, 61.9ms
# Speed: 1.8ms preprocess, 61.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 9 chairs, 1 couch, 1 dining table, 67.8ms
# Speed: 1.4ms preprocess, 67.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 handbag, 10 chairs, 1 couch, 1 dining table, 64.1ms
# Speed: 1.9ms preprocess, 64.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 backpack, 1 handbag, 10 chairs, 1 couch, 2 dining tables, 1 cell phone, 68.5ms
# Speed: 1.5ms preprocess, 68.5ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 backpack, 1 handbag, 8 chairs, 1 couch, 1 dining table, 74.2ms
# Speed: 1.8ms preprocess, 74.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 17
#      13     exit()
#      15 while True:
#      16     # Capture frame-by-frame
# ---> 17     ret, frame = cap.read()
#      19     if not ret:
#      20         print("Error: Failed to capture image.")
#
# KeyboardInterrupt:
